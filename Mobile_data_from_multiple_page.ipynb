# %%
import requests 
from bs4 import BeautifulSoup
import pandas as pd

# %%
url="https://www.flipkart.com/mobiles/pr?sid=tyy%2C4io&p%5B%5D=facets.brand%255B%255D%3DAPPLE&param=167811&ctx=eyJjYXJkQ29udGV4dCI6eyJhdHRyaWJ1dGVzIjp7InRpdGxlIjp7Im11bHRpVmFsdWVkQXR0cmlidXRlIjp7ImtleSI6InRpdGxlIiwiaW5mZXJlbmNlVHlwZSI6IlRJVExFIiwidmFsdWVzIjpbIkFwcGxlIFNtYXJ0cGhvbmVzIl0sInZhbHVlVHlwZSI6Ik1VTFRJX1ZBTFVFRCJ9fX19fQ%3D%3D&bu=MOBILE&wid=38.productCard.PMU_V2_31&sort=price_asc"

# %%
r=requests.get(url) 
r
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(r.text, "lxml")

# %% [markdown]
# # Iphone Data

# %%
data=soup.find_all("div",class_="yKfJKb row")
len(data)
# Out:
# 24

# %%
name=[]
star=[]
rating=[]
for i in data :
    nam=i.find_all("div",class_="KzDlHZ")
    st=i.find_all("div",class_="XQDdHH")
    rat=i.find_all("span",class_="Wphh3N")
    name.append(nam[0].get_text(strip=True))
    star.append(st[0].get_text(strip=True))
    rating.append(rat[0].get_text(strip=True))

# %%
ram=[] 
display=[] 
camera=[]
procesoor=[] 
warranty =[] 
for i in data :
    li=i.find_all("li",class_="J+igdf")
    ram.append(li[0].get_text(strip=True))
    display.append(li[1].get_text(strip=True))
    camera.append(li[2].get_text(strip=True))
    procesoor.append(li[2].get_text(strip=True))
    warranty.append(li[3].get_text(strip=True))

print(len(ram))
print(len(display))
print(len(camera))
print(len(procesoor))
print(len(warranty))
# Out:
# 24
# 24
# 24
# 24
# 24

# %%
price=[]
for d in data :
    pri=d.find_all("div",class_="Nx9bqj _4b5DiR")
    price.append(pri[0].get_text(strip=True))
print(price)
# Out:
# ['₹37,900', '₹39,900', '₹41,999', '₹41,999', '₹41,999', '₹41,999', '₹41,999', '₹41,999', '₹42,900', '₹44,999', '₹48,900', '₹48,900', '₹49,900', '₹49,999', '₹51,999', '₹51,999', '₹51,999', '₹51,999', '₹51,999', '₹51,999', '₹51,999', '₹51,999', '₹51,999', '₹51,999']

# %% [markdown]
# # Method for next tab data acess

# %%
link= soup.find("a",class_="cn++Ap A1msZJ").get("href")
print(link)
# Out:
# /mobiles/pr?sid=tyy%2C4io&p%5B%5D=facets.brand%255B%255D%3DAPPLE&param=167811&ctx=eyJjYXJkQ29udGV4dCI6eyJhdHRyaWJ1dGVzIjp7InRpdGxlIjp7Im11bHRpVmFsdWVkQXR0cmlidXRlIjp7ImtleSI6InRpdGxlIiwiaW5mZXJlbmNlVHlwZSI6IlRJVExFIiwidmFsdWVzIjpbIkFwcGxlIFNtYXJ0cGhvbmVzIl0sInZhbHVlVHlwZSI6Ik1VTFRJX1ZBTFVFRCJ9fX19fQ%3D%3D&bu=MOBILE&wid=38.productCard.PMU_V2_31&sort=price_asc&page=1

# %%
link="https://www.flipkart.com"+link

# %%
print(link)
# Out:
# https://www.flipkart.com/mobiles/pr?sid=tyy%2C4io&p%5B%5D=facets.brand%255B%255D%3DAPPLE&param=167811&ctx=eyJjYXJkQ29udGV4dCI6eyJhdHRyaWJ1dGVzIjp7InRpdGxlIjp7Im11bHRpVmFsdWVkQXR0cmlidXRlIjp7ImtleSI6InRpdGxlIiwiaW5mZXJlbmNlVHlwZSI6IlRJVExFIiwidmFsdWVzIjpbIkFwcGxlIFNtYXJ0cGhvbmVzIl0sInZhbHVlVHlwZSI6Ik1VTFRJX1ZBTFVFRCJ9fX19fQ%3D%3D&bu=MOBILE&wid=38.productCard.PMU_V2_31&sort=price_asc&page=1

# %% [markdown]
# # Extrct the iphone data

# %%
name=[]
star=[]
rating=[]
ram=[] 
display=[] 
camera=[]
procesoor=[] 
warranty =[] 
price=[]
for i in range(1,26):
    Url= "https://www.flipkart.com/mobiles/pr?sid=tyy%2C4io&p%5B%5D=facets.brand%255B%255D%3DAPPLE&param=167811&ctx=eyJjYXJkQ29udGV4dCI6eyJhdHRyaWJ1dGVzIjp7InRpdGxlIjp7Im11bHRpVmFsdWVkQXR0cmlidXRlIjp7ImtleSI6InRpdGxlIiwiaW5mZXJlbmNlVHlwZSI6IlRJVExFIiwidmFsdWVzIjpbIkFwcGxlIFNtYXJ0cGhvbmVzIl0sInZhbHVlVHlwZSI6Ik1VTFRJX1ZBTFVFRCJ9fX19fQ%3D%3D&bu=MOBILE&wid=38.productCard.PMU_V2_31&sort=price_asc&page="+str(i)
    R=requests.get(Url)
    soup=BeautifulSoup(R.text,"lxml")
    data_1=soup.find_all("div",class_="yKfJKb row")
    
    for i in data_1 :
        # finding name , star , rating 
        nam=i.find_all("div",class_="KzDlHZ")
        st=i.find_all("div",class_="XQDdHH")
        rat=i.find_all("span",class_="Wphh3N")
        name.append(nam[0].get_text(strip=True))
        star.append(st[0].get_text(strip=True))
        rating.append(rat[0].get_text(strip=True))
        # finding ram display , camera , and processor ..
        li=i.find_all("li",class_="J+igdf")
        length=len(li)
        ram.append(li[0].get_text(strip=True))
        display.append(li[1].get_text(strip=True))
        camera.append(li[2].get_text(strip=True))
        procesoor.append(li[3].get_text(strip=True))
        warranty.append(li[length-1].get_text(strip=True))
        #  finding price 
        pri=i.find_all("div",class_="Nx9bqj _4b5DiR")
        price.append(pri[0].get_text(strip=True))



df=pd.DataFrame({"Device Name":name ,"price":price, "star":star,"Ratings and review ":rating, "ROM":ram,"Display":display,"Camera":camera, "Processor":procesoor,"Warranty":warranty})
df
# Out:
#                                           Device Name      price star  \
# 0                        Apple iPhone 6 (Gold, 32 GB)    ₹30,780  4.4
# 1                      Apple iPhone 6 (Silver, 16 GB)    ₹36,990  4.4
# 2                  Apple iPhone 7 Plus (Black, 32 GB)    ₹37,900  4.5
# 3                      Apple iPhone 8 (Silver, 64 GB)    ₹39,900  4.5
# 4                       Apple iPhone 5C (Blue, 16 GB)    ₹41,900  3.9
# ..                                                ...        ...  ...
# 593     Apple iPhone 17 Pro Max (Cosmic Orange, 1 TB)  ₹1,89,900  4.8
# 594     Apple iPhone 15 Pro Max (Blue Titanium, 1 TB)  ₹1,99,900  4.6
# 595  Apple iPhone 15 Pro Max (Natural Titanium, 1 TB)  ₹1,99,900  4.6
# 596    Apple iPhone 15 Pro Max (Black Titanium, 1 TB)  ₹1,99,900  4.6
# 597    Apple iPhone 15 Pro Max (White Titanium, 1 TB)  ₹1,99,900  4.6
#
#                  Ratings and review         ROM  \
# 0    1,45,131 Ratings&16,062 Reviews  32 GB ROM
# ...

# %% [markdown]
# # Matrola Data

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
}

# lists
names = []
prices = []
ratings = []
stars = []
rams = []
displays = []
cameras = []
batteries = []
processors = []
warranties = []

for page in range(1, 16):
    Url = ("https://www.flipkart.com/mobiles/pr?sid=tyy%2C4io&p%5B%5D="
           "facets.brand%255B%255D%3DMOTOROLA&param=19873&ctx=eyJjYXJkQ29udGV4dCI6"
           "eyJhdHRyaWJ1dGVzIjp7InRpdGxlIjp7Im11bHRpVmFsdWVkQXR0cmlidXRlIjp7"
           "ImtleSI6InRpdGxlIiwiaW5mZXJlbmNlVHlwZSI6IlRJVExFIiwidmFsdWVzIjpb"
           "Ik1vdG9yb2xhIHNtYXJ0cGhvbmVzIl0sInZhbHVlVHlwZSI6Ik1VTFRJX1ZBTFVF"
           "RCJ9fX19fQ%3D%3D&bu=MOBILE&wid=39.productCard.PMU_V2_32&sort=price_asc"
           "&page=" + str(page))
    resp = requests.get(Url, headers=headers)
    if resp.status_code != 200:
        print(f"Page {page} returned status {resp.status_code}, skipping")
        time.sleep(1)
        continue

    soup = BeautifulSoup(resp.text, "lxml")
    cards = soup.find_all("div", class_="yKfJKb row")  

    for card in cards:
        # name, star, rating
        name_tag = card.find("div", class_="KzDlHZ")
        names.append(name_tag.get_text(strip=True) if name_tag else None)

        star_tag = card.find("div", class_="XQDdHH")
        stars.append(star_tag.get_text(strip=True) if star_tag else None)

        rating_tag = card.find("span", class_="Wphh3N")
        ratings.append(rating_tag.get_text(strip=True) if rating_tag else None)

        # features list
        li_items = card.find_all("li", class_="J+igdf")
        # defaults
        ram_val = display_val = camera_val = battery_val = proc_val = warranty_val = None

        for k in li_items:
            txt = k.get_text(strip=True)
            low = txt.lower()

            if ('rom' in low) or ('ram' in low):
                # prefer the li text itself (some pages show "4 GB RAM | 64 GB ROM")
                ram_val = txt
            elif ('display' in low) or ('inch' in low):
                display_val = txt
            elif ('camera' in low) or ('mp' in low):
                camera_val = txt
            elif ('battery' in low) or ('mah' in low):
                battery_val = txt
            elif ('processor' in low) or ('cpu' in low) or ('octa' in low):
                proc_val = txt
            elif ('warranty' in low) or ('year' in low):
                warranty_val = txt

        # append collected values (or None)
        rams.append(ram_val)
        displays.append(display_val)
        cameras.append(camera_val)
        batteries.append(battery_val)
        processors.append(proc_val)
        warranties.append(warranty_val)

        # price
        price_tag = card.find("div", class_="Nx9bqj _4b5DiR")
        prices.append(price_tag.get_text(strip=True) if price_tag else None)



# create DataFrame
df_mat = pd.DataFrame({
    "Device Name": names,
    "Price": prices,
    "Ratings and review": ratings,
    "Stars": stars,
    "ROM/RAM": rams,
    "Display": displays,
    "Camera": cameras,
    "Battery": batteries,
    "Processor": processors,
    "Warranty": warranties
})

df_mat.head()
# Out:
#                                          Device Name   Price  \
# 0  MOTOROLA A10V DS Keypad Phone with Voice Featu...  ₹1,292
# 1  MOTOROLA A10V DS Keypad Phone with Voice Featu...  ₹1,359
# 2                                 Motorola Moto A10E  ₹1,380
# 3                                 MOTOROLA Moto A300  ₹1,429
# 4  MOTOROLA A50V Dual Sim Keypad Phone|1750 mAh B...  ₹1,429
#
#           Ratings and review Stars  \
# 0  9,062 Ratings&576 Reviews   4.1
# 1  9,062 Ratings&576 Reviews   4.1
# 2  8,905 Ratings&600 Reviews     4
# 3     216 Ratings&16 Reviews     4
# 4   1,656 Ratings&80 Reviews   4.1
#
#                                           ROM/RAM  \
# 0    4 MB RAM | 32 MB ROM | Expandable Upto 64 GB
# 1    4 MB RAM | 32 MB ROM | Expandable Upto 64 GB
# 2                            4 MB RAM | 32 MB ROM
# 3    4 MB RAM | 32 MB ROM | Expandable Upto 64 GB
# 4  4 MB RAM | 0.05 GB ROM | Expandable Upto 32 GB
#
#                          Display                          Camera  \
# ...

# %% [markdown]
# #  Exract  the  Samsung data

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
}

# lists
names = []
prices = []
ratings = []
stars = []
rams = []
displays = []
cameras = []
batteries = []
processors = []
warranties = []

for page in range(1, 16):
    Url = ("https://www.flipkart.com/mobiles/pr?sid=tyy%2C4io&p%5B%5D=facets.availability%255B%255D%3DExclude%2BOut%2Bof%2BStock&param=178819&p%5B%5D=facets.brand%255B%255D%3DSAMSUNG&p%5B%5D=facets.type%255B%255D%3DSmartphones&ctx=eyJjYXJkQ29udGV4dCI6eyJhdHRyaWJ1dGVzIjp7InRpdGxlIjp7Im11bHRpVmFsdWVkQXR0cmlidXRlIjp7ImtleSI6InRpdGxlIiwiaW5mZXJlbmNlVHlwZSI6IlRJVExFIiwidmFsdWVzIjpbIlNhbXN1bmcgc21hcnRwaG9uZXMiXSwidmFsdWVUeXBlIjoiTVVMVElfVkFMVUVEIn19fX19&bu=MOBILE&wid=38.productCard.PMU_V2_33&sort=price_asc&page=" + str(page))
    resp = requests.get(Url, headers=headers, timeout=15)
    if resp.status_code != 200:
        print(f"Page {page} returned status {resp.status_code}, skipping")
        time.sleep(1)
        continue

    soup = BeautifulSoup(resp.text, "lxml")
    cards = soup.find_all("div", class_="yKfJKb row")  

    for card in cards:
        # name, star, rating
        name_tag = card.find("div", class_="KzDlHZ")
        names.append(name_tag.get_text(strip=True) if name_tag else None)

        star_tag = card.find("div", class_="XQDdHH")
        stars.append(star_tag.get_text(strip=True) if star_tag else None)

        rating_tag = card.find("span", class_="Wphh3N")
        ratings.append(rating_tag.get_text(strip=True) if rating_tag else None)

        # features list
        li_items = card.find_all("li", class_="J+igdf")
        # defaults
        ram_val = display_val = camera_val = battery_val = proc_val = warranty_val = None

        for k in li_items:
            txt = k.get_text(strip=True)
            low = txt.lower()

            if (' rom' in low) or ('ram' in low):
                # prefer the li text itself (some pages show "4 GB RAM | 64 GB ROM")
                ram_val = txt
            elif ('display' in low) or ('inch' in low):
                display_val = txt
            elif ('camera' in low) or ('mp' in low):
                camera_val = txt
            elif ('battery' in low) or ('mah' in low):
                battery_val = txt
            elif ('processor' in low) or ('cpu' in low) or ('octa' in low):
                proc_val = txt
            elif ('warranty' in low) or ('year' in low):
                warranty_val = txt

        # append collected values (or None)
        rams.append(ram_val)
        displays.append(display_val)
        cameras.append(camera_val)
        batteries.append(battery_val)
        processors.append(proc_val)
        warranties.append(warranty_val)

        # price
        price_tag = card.find("div", class_="Nx9bqj _4b5DiR")
        prices.append(price_tag.get_text(strip=True) if price_tag else None)

    time.sleep(0.8)  # polite delay

# create DataFrame
df_sumsung = pd.DataFrame({
    "Device Name": names,
    "Price": prices,
    "Ratings and review": ratings,
    "Stars": stars,
    "ROM/RAM": rams,
    "Display": displays,
    "Camera": cameras,
    "Battery": batteries,
    "Processor": processors,
    "Warranty": warranties
})

df_sumsung.head()
# Out:
#                                  Device Name   Price  \
# 0  Samsung Galaxy F05 (Twilight Blue, 64 GB)  ₹6,499
# 1          Samsung Galaxy F07 (Green, 64 GB)  ₹6,999
# 2            Samsung M05 (Mint Green, 64 GB)  ₹7,495
# 3          Samsung Galaxy M07 (Black, 64 GB)  ₹7,658
# 4          Samsung Galaxy A06 (Black, 64 GB)  ₹7,797
#
#              Ratings and review Stars  \
# 0  75,583 Ratings&4,080 Reviews   4.2
# 1      1,052 Ratings&59 Reviews   4.3
# 2     3,917 Ratings&163 Reviews   4.3
# 3           4 Ratings&0 Reviews   4.8
# 4        349 Ratings&21 Reviews   4.1
#
#                                        ROM/RAM  \
# 0  4 GB RAM | 64 GB ROM | Expandable Upto 1 TB
# 1  4 GB RAM | 64 GB ROM | Expandable Upto 2 TB
# 2                         4 GB RAM | 64 GB ROM
# 3  4 GB RAM | 64 GB ROM | Expandable Upto 2 TB
# 4  4 GB RAM | 64 GB ROM | Expandable Upto 1 TB
#
#                             Display                         Camera  \
# ...

# %%
t="1 year manufacturer warranty for device and 6 months manufacturer warranty for in-box accessories including batteries from the date of purchase"
t=t.lower()
print(t)
print(' rom'in t)
# Out:
# 1 year manufacturer warranty for device and 6 months manufacturer warranty for in-box accessories including batteries from the date of purchase
# False

# %% [markdown]
# #

# %% [markdown]
# # Vivo Data

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
}

# lists
names = []
prices = []
ratings = []
stars = []
rams = []
displays = []
cameras = []
batteries = []
processors = []
warranties = []

for page in range(1, 27):
    Url = ("https://www.flipkart.com/mobiles/pr?sid=tyy%2C4io&p%5B%5D=facets.brand%255B%255D%3Dvivo&param=1811&ctx=eyJjYXJkQ29udGV4dCI6eyJhdHRyaWJ1dGVzIjp7InRpdGxlIjp7Im11bHRpVmFsdWVkQXR0cmlidXRlIjp7ImtleSI6InRpdGxlIiwiaW5mZXJlbmNlVHlwZSI6IlRJVExFIiwidmFsdWVzIjpbIlZpdm8gc21hcnRwaG9uZXMiXSwidmFsdWVUeXBlIjoiTVVMVElfVkFMVUVEIn19fX19&bu=MOBILE&wid=39.productCard.PMU_V2_33&sort=price_asc&page=" + str(page))
    resp = requests.get(Url, headers=headers, timeout=15)
    if resp.status_code != 200:
        print(f"Page {page} returned status {resp.status_code}, skipping")
        time.sleep(1)
        continue

    soup = BeautifulSoup(resp.text, "lxml")
    cards = soup.find_all("div", class_="yKfJKb row")  

    for card in cards:
        # name, star, rating
        name_tag = card.find("div", class_="KzDlHZ")
        names.append(name_tag.get_text(strip=True) if name_tag else None)

        star_tag = card.find("div", class_="XQDdHH")
        stars.append(star_tag.get_text(strip=True) if star_tag else None)

        rating_tag = card.find("span", class_="Wphh3N")
        ratings.append(rating_tag.get_text(strip=True) if rating_tag else None)

        # features list
        li_items = card.find_all("li", class_="J+igdf")
        # defaults
        ram_val = display_val = camera_val = battery_val = proc_val = warranty_val = None

        for k in li_items:
            txt = k.get_text(strip=True)
            low = txt.lower()

            if (' rom' in low) or ('ram' in low):
                # prefer the li text itself (some pages show "4 GB RAM | 64 GB ROM")
                ram_val = txt
            elif ('display' in low) or ('inch' in low):
                display_val = txt
            elif ('camera' in low) or ('mp' in low):
                camera_val = txt
            elif ('battery' in low) or ('mah' in low):
                battery_val = txt
            elif ('processor' in low) or ('cpu' in low) or ('octa' in low):
                proc_val = txt
            elif ('warranty' in low) or ('year' in low):
                warranty_val = txt

        # append collected values (or None)
        rams.append(ram_val)
        displays.append(display_val)
        cameras.append(camera_val)
        batteries.append(battery_val)
        processors.append(proc_val)
        warranties.append(warranty_val)

        # price
        price_tag = card.find("div", class_="Nx9bqj _4b5DiR")
        prices.append(price_tag.get_text(strip=True) if price_tag else None)

    time.sleep(0.8)  # polite delay

# create DataFrame
df_vivo = pd.DataFrame({
    "Device Name": names,
    "Price": prices,
    "Ratings and review": ratings,
    "Stars": stars,
    "ROM/RAM": rams,
    "Display": displays,
    "Camera": cameras,
    "Battery": batteries,
    "Processor": processors,
    "Warranty": warranties
})

df_vivo
# Out:
#                           Device Name   Price        Ratings and review Stars  \
# 0  vivo Y19e (Titanium Silver, 64 GB)  ₹8,356  2,955 Ratings&99 Reviews   4.3
# 1   vivo Y19e (Majestic Green, 64 GB)  ₹8,390  2,955 Ratings&99 Reviews   4.3
# 2       vivo Y18t (Gem Green, 128 GB)  ₹8,499    837 Ratings&30 Reviews   4.2
# 3     vivo Y21E (Diamond Glow, 64 GB)  ₹9,424    546 Ratings&30 Reviews   4.3
# 4       vivo Y3s (Pearl white, 32 GB)  ₹9,490    333 Ratings&32 Reviews   4.3
#
#                                         ROM/RAM  \
# 0   4 GB RAM | 64 GB ROM | Expandable Upto 2 TB
# 1   4 GB RAM | 64 GB ROM | Expandable Upto 2 TB
# 2  4 GB RAM | 128 GB ROM | Expandable Upto 1 TB
# 3                          3 GB RAM | 64 GB ROM
# 4   2 GB RAM | 32 GB ROM | Expandable Upto 1 TB
#
#                             Display                               Camera  \
# 0      17.12 cm (6.74 inch) Display     13MP + 0.08MP | 5MP Front Camera
# ...

# %% [markdown]
# # Realme data

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
}

# lists
names = []
prices = []
ratings = []
stars = []
rams = []
displays = []
cameras = []
batteries = []
processors = []
warranties = []

for page in range(1, 38):
    Url = ("https://www.flipkart.com/mobiles/pr?sid=tyy%2C4io&p%5B%5D=facets.brand%255B%255D%3DRealme&param=1112&ctx=eyJjYXJkQ29udGV4dCI6eyJhdHRyaWJ1dGVzIjp7InRpdGxlIjp7Im11bHRpVmFsdWVkQXR0cmlidXRlIjp7ImtleSI6InRpdGxlIiwiaW5mZXJlbmNlVHlwZSI6IlRJVExFIiwidmFsdWVzIjpbIlJlYWxtZSBzbWFydHBob25lcyJdLCJ2YWx1ZVR5cGUiOiJNVUxUSV9WQUxVRUQifX19fX0%3D&bu=MOBILE&wid=40.productCard.PMU_V2_34&sort=price_asc&page=" + str(page))
    resp = requests.get(Url, headers=headers, timeout=20)
    if resp.status_code != 200:
        print(f"Page {page} returned status {resp.status_code}, skipping")
        time.sleep(1)
        continue

    soup = BeautifulSoup(resp.text, "lxml")
    cards = soup.find_all("div", class_="yKfJKb row")  

    for card in cards:
        # name, star, rating
        name_tag = card.find("div", class_="KzDlHZ")
        names.append(name_tag.get_text(strip=True) if name_tag else None)

        star_tag = card.find("div", class_="XQDdHH")
        stars.append(star_tag.get_text(strip=True) if star_tag else None)

        rating_tag = card.find("span", class_="Wphh3N")
        ratings.append(rating_tag.get_text(strip=True) if rating_tag else None)

        # features list
        li_items = card.find_all("li", class_="J+igdf")
        # defaults
        ram_val = display_val = camera_val = battery_val = proc_val = warranty_val = None

        for k in li_items:
            txt = k.get_text(strip=True)
            low = txt.lower()

            if (' rom' in low) or ('ram' in low):
                # prefer the li text itself (some pages show "4 GB RAM | 64 GB ROM")
                ram_val = txt
            elif ('display' in low) or ('inch' in low):
                display_val = txt
            elif ('camera' in low) or ('mp' in low):
                camera_val = txt
            elif ('battery' in low) or ('mah' in low):
                battery_val = txt
            elif ('processor' in low) or ('cpu' in low) or ('octa' in low):
                proc_val = txt
            elif ('warranty' in low) or ('year' in low):
                warranty_val = txt

        # append collected values (or None)
        rams.append(ram_val)
        displays.append(display_val)
        cameras.append(camera_val)
        batteries.append(battery_val)
        processors.append(proc_val)
        warranties.append(warranty_val)

        # price
        price_tag = card.find("div", class_="Nx9bqj _4b5DiR")
        prices.append(price_tag.get_text(strip=True) if price_tag else None)

    time.sleep(0.8)  # polite delay

# create DataFrame
df_realme = pd.DataFrame({
    "Device Name": names,
    "Price": prices,
    "Ratings and review": ratings,
    "Stars": stars,
    "ROM/RAM": rams,
    "Display": displays,
    "Camera": cameras,
    "Battery": batteries,
    "Processor": processors,
    "Warranty": warranties
})

df_realme
# Out:
#                                            Device Name    Price  \
# 0                     realme C61 (Safari Green, 64 GB)   ₹6,499
# 1                     realme C61 (Marble Black, 64 GB)   ₹6,499
# 2      realme Narzo 80 Lite 4G (Obsidian Black, 64 GB)   ₹7,199
# 3          realme Narzo 80 Lite 4G (Beach Gold, 64 GB)   ₹7,267
# 4                   realme C71 (Obsidian Black, 64 GB)   ₹7,349
# ..                                                 ...      ...
# 867                  realme X50 Pro (Rust Red, 128 GB)  ₹41,999
# 868               realme GT 5G (Racing Yellow, 256 GB)  ₹43,999
# 869  realme 15 Pro 5G Game of Thrones L.E (Dragonfi...  ₹44,999
# 870               realme X50 Pro 5G (Rust Red, 256 GB)  ₹47,999
# 871  realme GT7 Dream Edition 5G (Aston Martin Gree...  ₹47,999
#
#                Ratings and review Stars  \
# 0    34,844 Ratings&1,094 Reviews   4.4
# 1    34,844 Ratings&1,094 Reviews   4.4
# 2        1,307 Ratings&55 Reviews   4.3
# ...

# %% [markdown]
# #  Oppo Data

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
}

# lists
names = []
prices = []
ratings = []
stars = []
rams = []
displays = []
cameras = []
batteries = []
processors = []
warranties = []

for page in range(1, 12):
    Url = ("https://www.flipkart.com/mobiles/pr?sid=tyy%2C4io&p%5B%5D=facets.brand%255B%255D%3DOPPO&param=1001&ctx=eyJjYXJkQ29udGV4dCI6eyJhdHRyaWJ1dGVzIjp7InRpdGxlIjp7Im11bHRpVmFsdWVkQXR0cmlidXRlIjp7ImtleSI6InRpdGxlIiwiaW5mZXJlbmNlVHlwZSI6IlRJVExFIiwidmFsdWVzIjpbIk9wcG8gc21hcnRwaG9uZXMiXSwidmFsdWVUeXBlIjoiTVVMVElfVkFMVUVEIn19fX19&bu=MOBILE&wid=41.productCard.PMU_V2_35&sort=price_asc&page=" + str(page))
    resp = requests.get(Url, headers=headers, timeout=15)
    if resp.status_code != 200:
        print(f"Page {page} returned status {resp.status_code}, skipping")
        time.sleep(1)
        continue

    soup = BeautifulSoup(resp.text, "lxml")
    cards = soup.find_all("div", class_="yKfJKb row")  

    for card in cards:
        # name, star, rating
        name_tag = card.find("div", class_="KzDlHZ")
        names.append(name_tag.get_text(strip=True) if name_tag else None)

        star_tag = card.find("div", class_="XQDdHH")
        stars.append(star_tag.get_text(strip=True) if star_tag else None)

        rating_tag = card.find("span", class_="Wphh3N")
        ratings.append(rating_tag.get_text(strip=True) if rating_tag else None)

        # features list
        li_items = card.find_all("li", class_="J+igdf")
        # defaults
        ram_val = display_val = camera_val = battery_val = proc_val = warranty_val = None

        for k in li_items:
            txt = k.get_text(strip=True)
            low = txt.lower()

            if (' rom' in low) or ('ram' in low):
                # prefer the li text itself (some pages show "4 GB RAM | 64 GB ROM")
                ram_val = txt
            elif ('display' in low) or ('inch' in low):
                display_val = txt
            elif ('camera' in low) or ('mp' in low):
                camera_val = txt
            elif ('battery' in low) or ('mah' in low):
                battery_val = txt
            elif ('processor' in low) or ('cpu' in low) or ('octa' in low):
                proc_val = txt
            elif ('warranty' in low) or ('year' in low):
                warranty_val = txt

        # append collected values (or None)
        rams.append(ram_val)
        displays.append(display_val)
        cameras.append(camera_val)
        batteries.append(battery_val)
        processors.append(proc_val)
        warranties.append(warranty_val)

        # price
        price_tag = card.find("div", class_="Nx9bqj _4b5DiR")
        prices.append(price_tag.get_text(strip=True) if price_tag else None)

    time.sleep(0.8)  # polite delay

# create DataFrame
df_oppo = pd.DataFrame({
    "Device Name": names,
    "Price": prices,
    "Ratings and review": ratings,
    "Stars": stars,
    "ROM/RAM": rams,
    "Display": displays,
    "Camera": cameras,
    "Battery": batteries,
    "Processor": processors,
    "Warranty": warranties
})

df_oppo
# Out:
#                                     Device Name    Price  \
# 0                 OPPO A5x (Laser White, 64 GB)   ₹8,999
# 1                  OPPO A3x (Nebula Red, 64 GB)   ₹8,999
# 2               OPPO A5x (Midnight Blue, 64 GB)   ₹8,999
# 3                 OPPO A3x (Nebula Red, 128 GB)   ₹9,599
# 4              OPPO A5x (Midnight Blue, 128 GB)   ₹9,999
# ..                                          ...      ...
# 240      OPPO Find N3 Flip (Cream Gold, 256 GB)  ₹48,990
# 241  OPPO Reno14 Pro 5G (Titanium Grey, 512 GB)  ₹56,999
# 242       OPPO Find X8 5G (Space Black, 512 GB)  ₹69,000
# 243       OPPO Find X8 5G (Space Black, 256 GB)  ₹69,999
# 244     OPPO Find N3 Flip (Sleek Black, 256 GB)  ₹74,999
#
#             Ratings and review Stars  \
# 0         42 Ratings&4 Reviews   4.3
# 1     1,603 Ratings&84 Reviews   4.1
# 2         42 Ratings&4 Reviews   4.3
# 3     1,603 Ratings&84 Reviews   4.1
# 4         42 Ratings&4 Reviews   4.3
# ..                         ...   ...
# ...

# %% [markdown]
# #  Redmi Data

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
}

# lists
names = []
prices = []
ratings = []
stars = []
rams = []
displays = []
cameras = []
batteries = []
processors = []
warranties = []

for page in range(1, 27):
    Url = ("https://www.flipkart.com/mobiles/pr?sid=tyy%2C4io&p%5B%5D=facets.brand%255B%255D%3DREDMI&param=110082&ctx=eyJjYXJkQ29udGV4dCI6eyJhdHRyaWJ1dGVzIjp7InRpdGxlIjp7Im11bHRpVmFsdWVkQXR0cmlidXRlIjp7ImtleSI6InRpdGxlIiwiaW5mZXJlbmNlVHlwZSI6IlRJVExFIiwidmFsdWVzIjpbIlJlZG1pIHNtYXJ0cGhvbmVzIl0sInZhbHVlVHlwZSI6Ik1VTFRJX1ZBTFVFRCJ9fX19fQ%3D%3D&bu=MOBILE&wid=42.productCard.PMU_V2_36&sort=price_asc&page=" + str(page))
    resp = requests.get(Url, headers=headers, timeout=15)
    if resp.status_code != 200:
        print(f"Page {page} returned status {resp.status_code}, skipping")
        time.sleep(1)
        continue

    soup = BeautifulSoup(resp.text, "lxml")
    cards = soup.find_all("div", class_="yKfJKb row")  

    for card in cards:
        # name, star, rating
        name_tag = card.find("div", class_="KzDlHZ")
        names.append(name_tag.get_text(strip=True) if name_tag else None)

        star_tag = card.find("div", class_="XQDdHH")
        stars.append(star_tag.get_text(strip=True) if star_tag else None)

        rating_tag = card.find("span", class_="Wphh3N")
        ratings.append(rating_tag.get_text(strip=True) if rating_tag else None)

        # features list
        li_items = card.find_all("li", class_="J+igdf")
        # defaults
        ram_val = display_val = camera_val = battery_val = proc_val = warranty_val = None

        for k in li_items:
            txt = k.get_text(strip=True)
            low = txt.lower()

            if (' rom' in low) or ('ram' in low):
                # prefer the li text itself (some pages show "4 GB RAM | 64 GB ROM")
                ram_val = txt
            elif ('display' in low) or ('inch' in low):
                display_val = txt
            elif ('camera' in low) or ('mp' in low):
                camera_val = txt
            elif ('battery' in low) and ('mah' in low):
                battery_val = txt
            elif ('processor' in low) or ('cpu' in low) or ('octa' in low):
                proc_val = txt
            elif ('warranty' in low) or ('year' in low):
                warranty_val = txt

        # append collected values (or None)
        rams.append(ram_val)
        displays.append(display_val)
        cameras.append(camera_val)
        batteries.append(battery_val)
        processors.append(proc_val)
        warranties.append(warranty_val)

        # price
        price_tag = card.find("div", class_="Nx9bqj _4b5DiR")
        prices.append(price_tag.get_text(strip=True) if price_tag else None)

    time.sleep(0.8)  # polite delay

# create DataFrame
df_redmi = pd.DataFrame({
    "Device Name": names,
    "Price": prices,
    "Ratings and review": ratings,
    "Stars": stars,
    "ROM/RAM": rams,
    "Display": displays,
    "Camera": cameras,
    "Battery": batteries,
    "Processor": processors,
    "Warranty": warranties
})

df_redmi
# Out:
#                                            Device Name    Price  \
# 0                                REDMI Go (Blue, 8 GB)   ₹4,499
# 1    REDMI A5  - Locked with Airtel Prepaid (Jaisal...   ₹5,999
# 2    REDMI A5  - Locked with Airtel Prepaid (Pondic...   ₹5,999
# 3    REDMI A5  - Locked with Airtel Prepaid (Just B...   ₹5,999
# 4                        REDMI A2+ (Aqua Blue, 128 GB)   ₹6,322
# ..                                                 ...      ...
# 597       REDMI Note 14 Pro+ 5G (Spectre Blue, 512 GB)  ₹31,999
# 598     REDMI Note 14 Pro+ 5G (Phantom Purple, 512 GB)  ₹31,999
# 599     REDMI Note 14 Pro+ 5G (Champagne Gold, 512 GB)  ₹31,999
# 600  REDMI Note 13 Pro+ 5G (World Champions Edition...  ₹33,499
# 601  REDMI 14 CIVI (MATCHA GREEN, CRUISE BLUE, SHAD...  ₹36,499
#
#                Ratings and review Stars  \
# 0            48 Ratings&8 Reviews   3.3
# 1       5,345 Ratings&243 Reviews   4.1
# 2       5,345 Ratings&243 Reviews   4.1
# ...

# %% [markdown]
# # Poco Data

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
}

# lists
names = []
prices = []
ratings = []
stars = []
rams = []
displays = []
cameras = []
batteries = []
processors = []
warranties = []

for page in range(1, 15):
    Url = ("https://www.flipkart.com/mobiles/pr?sid=tyy%2C4io&p%5B%5D=facets.brand%255B%255D%3DPOCO&param=0001&ctx=eyJjYXJkQ29udGV4dCI6eyJhdHRyaWJ1dGVzIjp7InRpdGxlIjp7Im11bHRpVmFsdWVkQXR0cmlidXRlIjp7ImtleSI6InRpdGxlIiwiaW5mZXJlbmNlVHlwZSI6IlRJVExFIiwidmFsdWVzIjpbIlBvY28gc21hcnRwaG9uZXMiXSwidmFsdWVUeXBlIjoiTVVMVElfVkFMVUVEIn19fX19&bu=MOBILE&wid=43.productCard.PMU_V2_37&sort=price_asc&page=" + str(page))
    resp = requests.get(Url, headers=headers, timeout=15)
    if resp.status_code != 200:
        print(f"Page {page} returned status {resp.status_code}, skipping")
        time.sleep(1)
        continue

    soup = BeautifulSoup(resp.text, "lxml")
    cards = soup.find_all("div", class_="yKfJKb row")  

    for card in cards:
        # name, star, rating
        name_tag = card.find("div", class_="KzDlHZ")
        names.append(name_tag.get_text(strip=True) if name_tag else None)

        star_tag = card.find("div", class_="XQDdHH")
        stars.append(star_tag.get_text(strip=True) if star_tag else None)

        rating_tag = card.find("span", class_="Wphh3N")
        ratings.append(rating_tag.get_text(strip=True) if rating_tag else None)

        # features list
        li_items = card.find_all("li", class_="J+igdf")
        # defaults
        ram_val = display_val = camera_val = battery_val = proc_val = warranty_val = None

        for k in li_items:
            txt = k.get_text(strip=True)
            low = txt.lower()

            if (' rom' in low) or ('ram' in low):
                # prefer the li text itself (some pages show "4 GB RAM | 64 GB ROM")
                ram_val = txt
            elif ('display' in low) or ('inch' in low):
                display_val = txt
            elif ('camera' in low) or ('mp' in low):
                camera_val = txt
            elif ('battery' in low) or ('mah' in low):
                battery_val = txt
            elif ('processor' in low) or ('cpu' in low) or ('octa' in low):
                proc_val = txt
            elif ('warranty' in low) or ('year' in low):
                warranty_val = txt

        # append collected values (or None)
        rams.append(ram_val)
        displays.append(display_val)
        cameras.append(camera_val)
        batteries.append(battery_val)
        processors.append(proc_val)
        warranties.append(warranty_val)

        # price
        price_tag = card.find("div", class_="Nx9bqj _4b5DiR")
        prices.append(price_tag.get_text(strip=True) if price_tag else None)

    time.sleep(0.8)  # polite delay

# create DataFrame
df_poco = pd.DataFrame({
    "Device Name": names,
    "Price": prices,
    "Ratings and review": ratings,
    "Stars": stars,
    "ROM/RAM": rams,
    "Display": displays,
    "Camera": cameras,
    "Battery": batteries,
    "Processor": processors,
    "Warranty": warranties
})

df_poco
# Out:
#                                            Device Name    Price  \
# 0    POCO C71  - Locked with Airtel Prepaid (Cool B...   ₹5,749
# 1    POCO C71  - Locked with Airtel Prepaid (Desert...   ₹5,749
# 2    POCO C71  - Locked with Airtel Prepaid (Power ...   ₹5,749
# 3                      POCO C61 (Ethereal Blue, 64 GB)   ₹5,945
# 4                        POCO C71 (Desert Gold, 64 GB)   ₹6,199
# ..                                                 ...      ...
# 316               POCO F5 5G (Snowstorm White, 256 GB)  ₹29,999
# 317             POCO F3 GT 5G (Predator Black, 256 GB)  ₹30,999
# 318            POCO F3 GT 5G (Gunmetal Silver, 256 GB)  ₹30,999
# 319                 POCO F5 5G (Electric Blue, 256 GB)  ₹33,999
# 320               POCO F5 5G (Snowstorm White, 256 GB)  ₹33,999
#
#                  Ratings and review Stars  \
# 0      48,091 Ratings&2,198 Reviews   3.8
# 1      48,091 Ratings&2,198 Reviews   3.8
# 2      48,091 Ratings&2,198 Reviews   3.8
# ...

# %% [markdown]
# # Google Mobile Data

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
}

# lists
names = []
prices = []
ratings = []
stars = []
rams = []
displays = []
cameras = []
batteries = []
processors = []
warranties = []

for page in range(1, 4):
    Url = ("https://www.flipkart.com/mobiles/pr?sid=tyy%2C4io&p%5B%5D=facets.brand%255B%255D%3DGoogle&param=16161&ctx=eyJjYXJkQ29udGV4dCI6eyJhdHRyaWJ1dGVzIjp7InRpdGxlIjp7Im11bHRpVmFsdWVkQXR0cmlidXRlIjp7ImtleSI6InRpdGxlIiwiaW5mZXJlbmNlVHlwZSI6IlRJVExFIiwidmFsdWVzIjpbIkdvb2dsZSBzbWFydHBob25lcyJdLCJ2YWx1ZVR5cGUiOiJNVUxUSV9WQUxVRUQifX19fX0%3D&bu=MOBILE&wid=44.productCard.PMU_V2_38&sort=price_asc&page=" + str(page))
    resp = requests.get(Url, headers=headers, timeout=15)
    if resp.status_code != 200:
        print(f"Page {page} returned status {resp.status_code}, skipping")
        time.sleep(1)
        continue

    soup = BeautifulSoup(resp.text, "lxml")
    cards = soup.find_all("div", class_="yKfJKb row")  

    for card in cards:
        # name, star, rating
        name_tag = card.find("div", class_="KzDlHZ")
        names.append(name_tag.get_text(strip=True) if name_tag else None)

        star_tag = card.find("div", class_="XQDdHH")
        stars.append(star_tag.get_text(strip=True) if star_tag else None)

        rating_tag = card.find("span", class_="Wphh3N")
        ratings.append(rating_tag.get_text(strip=True) if rating_tag else None)

        # features list
        li_items = card.find_all("li", class_="J+igdf")
        # defaults
        ram_val = display_val = camera_val = battery_val = proc_val = warranty_val = None

        for k in li_items:
            txt = k.get_text(strip=True)
            low = txt.lower()

            if (' rom' in low) or ('ram' in low):
                # prefer the li text itself (some pages show "4 GB RAM | 64 GB ROM")
                ram_val = txt
            elif ('display' in low) or ('inch' in low):
                display_val = txt
            elif ('camera' in low) or ('mp' in low):
                camera_val = txt
            elif ('battery' in low) or ('mah' in low):
                battery_val = txt
            elif ('processor' in low) or ('cpu' in low) or ('octa' in low):
                proc_val = txt
            elif ('warranty' in low) or ('year' in low):
                warranty_val = txt

        # append collected values (or None)
        rams.append(ram_val)
        displays.append(display_val)
        cameras.append(camera_val)
        batteries.append(battery_val)
        processors.append(proc_val)
        warranties.append(warranty_val)

        # price
        price_tag = card.find("div", class_="Nx9bqj _4b5DiR")
        prices.append(price_tag.get_text(strip=True) if price_tag else None)

    time.sleep(0.8)  # polite delay

# create DataFrame
df_google = pd.DataFrame({
    "Device Name": names,
    "Price": prices,
    "Ratings and review": ratings,
    "Stars": stars,
    "ROM/RAM": rams,
    "Display": displays,
    "Camera": cameras,
    "Battery": batteries,
    "Processor": processors,
    "Warranty": warranties
})

df_google
# Out:
#                                      Device Name      Price  \
# 0                  Google GP 3XL (White, 128 GB)    ₹21,216
# 1                Google Pixel 6a (Chalk, 128 GB)    ₹24,999
# 2                  Google Pixel 7a (Sea, 128 GB)    ₹28,999
# 3             Google Pixel 7a (Charcoal, 128 GB)    ₹28,999
# 4                 Google Pixel 7a (Snow, 128 GB)    ₹28,999
# ..                                           ...        ...
# 56    Google Pixel 9 Pro Fold (Obsidian, 256 GB)  ₹1,19,999
# 57         Google Pixel 10 Pro XL (Jade, 256 GB)  ₹1,24,995
# 58     Google Pixel 10 Pro XL (Obsidian, 256 GB)  ₹1,24,999
# 59    Google Pixel 10 Pro XL (Moonstone, 256 GB)  ₹1,24,999
# 60  Google Pixel 10 Pro Fold (Moonstone, 256 GB)  ₹1,72,999
#
#               Ratings and review Stars                 ROM/RAM  \
# 0                           None  None   4 GB RAM | 128 GB ROM
# 1   75,960 Ratings&8,527 Reviews   4.3   6 GB RAM | 128 GB ROM
# ...

# %% [markdown]
# # Infinix Data

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
}

# lists
names = []
prices = []
ratings = []
stars = []
rams = []
displays = []
cameras = []
batteries = []
processors = []
warranties = []

for page in range(1, 16):
    Url = ("https://www.flipkart.com/mobiles/pr?sid=tyy%2C4io&p%5B%5D=facets.brand%255B%255D%3DInfinix&param=9872&ctx=eyJjYXJkQ29udGV4dCI6eyJhdHRyaWJ1dGVzIjp7InRpdGxlIjp7Im11bHRpVmFsdWVkQXR0cmlidXRlIjp7ImtleSI6InRpdGxlIiwiaW5mZXJlbmNlVHlwZSI6IlRJVExFIiwidmFsdWVzIjpbIkluZmluaXggc21hcnRwaG9uZXMiXSwidmFsdWVUeXBlIjoiTVVMVElfVkFMVUVEIn19fX19&bu=MOBILE&wid=45.productCard.PMU_V2_39&sort=price_asc&page=" + str(page))
    resp = requests.get(Url, headers=headers, timeout=15)
    if resp.status_code != 200:
        print(f"Page {page} returned status {resp.status_code}, skipping")
        time.sleep(1)
        continue

    soup = BeautifulSoup(resp.text, "lxml")
    cards = soup.find_all("div", class_="yKfJKb row")  

    for card in cards:
        # name, star, rating
        name_tag = card.find("div", class_="KzDlHZ")
        names.append(name_tag.get_text(strip=True) if name_tag else None)

        star_tag = card.find("div", class_="XQDdHH")
        stars.append(star_tag.get_text(strip=True) if star_tag else None)

        rating_tag = card.find("span", class_="Wphh3N")
        ratings.append(rating_tag.get_text(strip=True) if rating_tag else None)

        # features list
        li_items = card.find_all("li", class_="J+igdf")
        # defaults
        ram_val = display_val = camera_val = battery_val = proc_val = warranty_val = None

        for k in li_items:
            txt = k.get_text(strip=True)
            low = txt.lower()

            if (' rom' in low) or ('ram' in low):
                # prefer the li text itself (some pages show "4 GB RAM | 64 GB ROM")
                ram_val = txt
            elif ('display' in low) or ('inch' in low):
                display_val = txt
            elif ('camera' in low) or ('mp' in low):
                camera_val = txt
            elif ('battery' in low) or ('mah' in low):
                battery_val = txt
            elif ('processor' in low) or ('cpu' in low) or ('octa' in low):
                proc_val = txt
            elif ('warranty' in low) or ('year' in low):
                warranty_val = txt

        # append collected values (or None)
        rams.append(ram_val)
        displays.append(display_val)
        cameras.append(camera_val)
        batteries.append(battery_val)
        processors.append(proc_val)
        warranties.append(warranty_val)

        # price
        price_tag = card.find("div", class_="Nx9bqj _4b5DiR")
        prices.append(price_tag.get_text(strip=True) if price_tag else None)

    time.sleep(0.8)  # polite delay

# create DataFrame
df_infinix = pd.DataFrame({
    "Device Name": names,
    "Price": prices,
    "Ratings and review": ratings,
    "Stars": stars,
    "ROM/RAM": rams,
    "Display": displays,
    "Camera": cameras,
    "Battery": batteries,
    "Processor": processors,
    "Warranty": warranties
})

df_infinix
# Out:
#                                       Device Name    Price  \
# 0          Infinix SMART 9 HD (Coral Gold, 64 GB)   ₹6,699
# 1          Infinix SMART 9 HD (Mint Green, 64 GB)   ₹6,699
# 2      Infinix SMART 9 HD (Metallic Black, 64 GB)   ₹6,699
# 3        Infinix SMART 9 HD (Neo Titanium, 64 GB)   ₹6,699
# 4        Infinix SMART 8 HD (Timber Black, 64 GB)   ₹6,699
# ..                                            ...      ...
# 337       Infinix Zero 40 5G (Rock Black, 512 GB)  ₹30,999
# 338  Infinix Zero 40 5G (Moving Titanium, 512 GB)  ₹30,999
# 339    Infinix Zero 40 5G (Violet Garden, 512 GB)  ₹30,999
# 340  Infinix Zero Ultra (Coslight Silver, 256 GB)  ₹36,999
# 341   Infinix Zero Flip 5G (Blossom Glow, 512 GB)  ₹54,999
#
#                Ratings and review Stars  \
# 0       4,326 Ratings&261 Reviews   4.1
# 1       4,326 Ratings&261 Reviews   4.1
# 2       4,326 Ratings&261 Reviews   4.1
# 3       4,326 Ratings&261 Reviews   4.1
# 4    46,695 Ratings&2,822 Reviews   4.3
# ...

# %%
df
# Out:
#                                           Device Name      price star  \
# 0                        Apple iPhone 6 (Gold, 32 GB)    ₹30,780  4.4
# 1                      Apple iPhone 6 (Silver, 16 GB)    ₹36,990  4.4
# 2                  Apple iPhone 7 Plus (Black, 32 GB)    ₹37,900  4.5
# 3                      Apple iPhone 8 (Silver, 64 GB)    ₹39,900  4.5
# 4                       Apple iPhone 5C (Blue, 16 GB)    ₹41,900  3.9
# ..                                                ...        ...  ...
# 593     Apple iPhone 17 Pro Max (Cosmic Orange, 1 TB)  ₹1,89,900  4.8
# 594     Apple iPhone 15 Pro Max (Blue Titanium, 1 TB)  ₹1,99,900  4.6
# 595  Apple iPhone 15 Pro Max (Natural Titanium, 1 TB)  ₹1,99,900  4.6
# 596    Apple iPhone 15 Pro Max (Black Titanium, 1 TB)  ₹1,99,900  4.6
# 597    Apple iPhone 15 Pro Max (White Titanium, 1 TB)  ₹1,99,900  4.6
#
#                  Ratings and review         ROM  \
# 0    1,45,131 Ratings&16,062 Reviews  32 GB ROM
# ...

# %%
df_mat
# Out:
#                                            Device Name    Price  \
# 0    MOTOROLA A10V DS Keypad Phone with Voice Featu...   ₹1,292
# 1    MOTOROLA A10V DS Keypad Phone with Voice Featu...   ₹1,359
# 2                                   Motorola Moto A10E   ₹1,380
# 3                                   MOTOROLA Moto A300   ₹1,429
# 4    MOTOROLA A50V Dual Sim Keypad Phone|1750 mAh B...   ₹1,429
# ..                                                 ...      ...
# 337      MOTOROLA Razr 50 Ultra (Spring Green, 512 GB)  ₹59,450
# 338        MOTOROLA Razar 50 Flip (Beach Sand, 256 GB)  ₹59,999
# 339     MOTOROLA Razar 50 Flip (Spritz Orange, 256 GB)  ₹72,999
# 340             MOTOROLA Razar 40 (Sage Green, 256 GB)  ₹88,888
# 341  MOTOROLA Razr 60 Ultra (Pantone Mountain Trail...  ₹89,899
#
#             Ratings and review Stars  \
# 0    9,062 Ratings&576 Reviews   4.1
# 1    9,062 Ratings&576 Reviews   4.1
# 2    8,905 Ratings&600 Reviews     4
# 3       216 Ratings&16 Reviews     4
# ...

# %%
df_sumsung
# Out:
#                                            Device Name    Price  \
# 0            Samsung Galaxy F05 (Twilight Blue, 64 GB)   ₹6,499
# 1                    Samsung Galaxy F07 (Green, 64 GB)   ₹6,999
# 2                      Samsung M05 (Mint Green, 64 GB)   ₹7,495
# 3                    Samsung Galaxy M07 (Black, 64 GB)   ₹7,658
# 4                    Samsung Galaxy A06 (Black, 64 GB)   ₹7,797
# ..                                                 ...      ...
# 355  Samsung Galaxy S24 Exynos 5G (Onyx Black, 512 GB)  ₹89,999
# 356       Samsung Galaxy Z Flip7 FE 5G (White, 128 GB)  ₹89,999
# 357  Samsung Galaxy S24 Exynos 5G (Amber Yellow, 51...  ₹89,999
# 358  Samsung Galaxy S25 Edge 5G (Titanium Silver, 2...  ₹89,999
# 359  Samsung Galaxy Z Flip6 5G (Silver Shadow, 256 GB)  ₹89,999
#
#                Ratings and review Stars  \
# 0    75,583 Ratings&4,080 Reviews   4.2
# 1        1,052 Ratings&59 Reviews   4.3
# 2       3,917 Ratings&163 Reviews   4.3
# ...

# %%
df_vivo
# Out:
#                               Device Name    Price         Ratings and review  \
# 0      vivo Y19e (Titanium Silver, 64 GB)   ₹8,356   2,955 Ratings&99 Reviews
# 1       vivo Y19e (Majestic Green, 64 GB)   ₹8,390   2,955 Ratings&99 Reviews
# 2           vivo Y18t (Gem Green, 128 GB)   ₹8,499     837 Ratings&30 Reviews
# 3         vivo Y21E (Diamond Glow, 64 GB)   ₹9,424     546 Ratings&30 Reviews
# 4           vivo Y3s (Pearl white, 32 GB)   ₹9,490     333 Ratings&32 Reviews
# ..                                    ...      ...                        ...
# 609  vivo X200 5G (Natural Green, 256 GB)  ₹65,999  1,311 Ratings&213 Reviews
# 610     vivo X100 (Stargaze Blue, 512 GB)  ₹69,999     365 Ratings&66 Reviews
# 611   vivo X200 5G (Cosmos Black, 512 GB)  ₹71,999     263 Ratings&34 Reviews
# 612  vivo X200 5G (Natural Green, 512 GB)  ₹71,999     263 Ratings&34 Reviews
# 613       vivo X70 Pro+ (EnBlack, 256 GB)  ₹79,990    573 Ratings&116 Reviews
#
# ...

# %%
df_realme
# Out:
#                                            Device Name    Price  \
# 0                     realme C61 (Safari Green, 64 GB)   ₹6,499
# 1                     realme C61 (Marble Black, 64 GB)   ₹6,499
# 2      realme Narzo 80 Lite 4G (Obsidian Black, 64 GB)   ₹7,199
# 3          realme Narzo 80 Lite 4G (Beach Gold, 64 GB)   ₹7,267
# 4                   realme C71 (Obsidian Black, 64 GB)   ₹7,349
# ..                                                 ...      ...
# 867                  realme X50 Pro (Rust Red, 128 GB)  ₹41,999
# 868               realme GT 5G (Racing Yellow, 256 GB)  ₹43,999
# 869  realme 15 Pro 5G Game of Thrones L.E (Dragonfi...  ₹44,999
# 870               realme X50 Pro 5G (Rust Red, 256 GB)  ₹47,999
# 871  realme GT7 Dream Edition 5G (Aston Martin Gree...  ₹47,999
#
#                Ratings and review Stars  \
# 0    34,844 Ratings&1,094 Reviews   4.4
# 1    34,844 Ratings&1,094 Reviews   4.4
# 2        1,307 Ratings&55 Reviews   4.3
# ...

# %%
df_oppo
# Out:
#                                     Device Name    Price  \
# 0                 OPPO A5x (Laser White, 64 GB)   ₹8,999
# 1                  OPPO A3x (Nebula Red, 64 GB)   ₹8,999
# 2               OPPO A5x (Midnight Blue, 64 GB)   ₹8,999
# 3                 OPPO A3x (Nebula Red, 128 GB)   ₹9,599
# 4              OPPO A5x (Midnight Blue, 128 GB)   ₹9,999
# ..                                          ...      ...
# 240      OPPO Find N3 Flip (Cream Gold, 256 GB)  ₹48,990
# 241  OPPO Reno14 Pro 5G (Titanium Grey, 512 GB)  ₹56,999
# 242       OPPO Find X8 5G (Space Black, 512 GB)  ₹69,000
# 243       OPPO Find X8 5G (Space Black, 256 GB)  ₹69,999
# 244     OPPO Find N3 Flip (Sleek Black, 256 GB)  ₹74,999
#
#             Ratings and review Stars  \
# 0         42 Ratings&4 Reviews   4.3
# 1     1,603 Ratings&84 Reviews   4.1
# 2         42 Ratings&4 Reviews   4.3
# 3     1,603 Ratings&84 Reviews   4.1
# 4         42 Ratings&4 Reviews   4.3
# ..                         ...   ...
# ...

# %%
df_redmi
# Out:
#                                            Device Name    Price  \
# 0                                REDMI Go (Blue, 8 GB)   ₹4,499
# 1    REDMI A5  - Locked with Airtel Prepaid (Jaisal...   ₹5,999
# 2    REDMI A5  - Locked with Airtel Prepaid (Pondic...   ₹5,999
# 3    REDMI A5  - Locked with Airtel Prepaid (Just B...   ₹5,999
# 4                        REDMI A2+ (Aqua Blue, 128 GB)   ₹6,322
# ..                                                 ...      ...
# 597       REDMI Note 14 Pro+ 5G (Spectre Blue, 512 GB)  ₹31,999
# 598     REDMI Note 14 Pro+ 5G (Phantom Purple, 512 GB)  ₹31,999
# 599     REDMI Note 14 Pro+ 5G (Champagne Gold, 512 GB)  ₹31,999
# 600  REDMI Note 13 Pro+ 5G (World Champions Edition...  ₹33,499
# 601  REDMI 14 CIVI (MATCHA GREEN, CRUISE BLUE, SHAD...  ₹36,499
#
#                Ratings and review Stars  \
# 0            48 Ratings&8 Reviews   3.3
# 1       5,345 Ratings&243 Reviews   4.1
# 2       5,345 Ratings&243 Reviews   4.1
# ...

# %%
df_poco
# Out:
#                                            Device Name    Price  \
# 0    POCO C71  - Locked with Airtel Prepaid (Cool B...   ₹5,749
# 1    POCO C71  - Locked with Airtel Prepaid (Desert...   ₹5,749
# 2    POCO C71  - Locked with Airtel Prepaid (Power ...   ₹5,749
# 3                      POCO C61 (Ethereal Blue, 64 GB)   ₹5,945
# 4                        POCO C71 (Desert Gold, 64 GB)   ₹6,199
# ..                                                 ...      ...
# 316               POCO F5 5G (Snowstorm White, 256 GB)  ₹29,999
# 317             POCO F3 GT 5G (Predator Black, 256 GB)  ₹30,999
# 318            POCO F3 GT 5G (Gunmetal Silver, 256 GB)  ₹30,999
# 319                 POCO F5 5G (Electric Blue, 256 GB)  ₹33,999
# 320               POCO F5 5G (Snowstorm White, 256 GB)  ₹33,999
#
#                  Ratings and review Stars  \
# 0      48,091 Ratings&2,198 Reviews   3.8
# 1      48,091 Ratings&2,198 Reviews   3.8
# 2      48,091 Ratings&2,198 Reviews   3.8
# ...

# %%
df_google
# Out:
#                                      Device Name      Price  \
# 0                  Google GP 3XL (White, 128 GB)    ₹21,216
# 1                Google Pixel 6a (Chalk, 128 GB)    ₹24,999
# 2                  Google Pixel 7a (Sea, 128 GB)    ₹28,999
# 3             Google Pixel 7a (Charcoal, 128 GB)    ₹28,999
# 4                 Google Pixel 7a (Snow, 128 GB)    ₹28,999
# ..                                           ...        ...
# 56    Google Pixel 9 Pro Fold (Obsidian, 256 GB)  ₹1,19,999
# 57         Google Pixel 10 Pro XL (Jade, 256 GB)  ₹1,24,995
# 58     Google Pixel 10 Pro XL (Obsidian, 256 GB)  ₹1,24,999
# 59    Google Pixel 10 Pro XL (Moonstone, 256 GB)  ₹1,24,999
# 60  Google Pixel 10 Pro Fold (Moonstone, 256 GB)  ₹1,72,999
#
#               Ratings and review Stars                 ROM/RAM  \
# 0                           None  None   4 GB RAM | 128 GB ROM
# 1   75,960 Ratings&8,527 Reviews   4.3   6 GB RAM | 128 GB ROM
# ...

# %%
df_infinix
# Out:
#                                       Device Name    Price  \
# 0          Infinix SMART 9 HD (Coral Gold, 64 GB)   ₹6,699
# 1          Infinix SMART 9 HD (Mint Green, 64 GB)   ₹6,699
# 2      Infinix SMART 9 HD (Metallic Black, 64 GB)   ₹6,699
# 3        Infinix SMART 9 HD (Neo Titanium, 64 GB)   ₹6,699
# 4        Infinix SMART 8 HD (Timber Black, 64 GB)   ₹6,699
# ..                                            ...      ...
# 337       Infinix Zero 40 5G (Rock Black, 512 GB)  ₹30,999
# 338  Infinix Zero 40 5G (Moving Titanium, 512 GB)  ₹30,999
# 339    Infinix Zero 40 5G (Violet Garden, 512 GB)  ₹30,999
# 340  Infinix Zero Ultra (Coslight Silver, 256 GB)  ₹36,999
# 341   Infinix Zero Flip 5G (Blossom Glow, 512 GB)  ₹54,999
#
#                Ratings and review Stars  \
# 0       4,326 Ratings&261 Reviews   4.1
# 1       4,326 Ratings&261 Reviews   4.1
# 2       4,326 Ratings&261 Reviews   4.1
# 3       4,326 Ratings&261 Reviews   4.1
# 4    46,695 Ratings&2,822 Reviews   4.3
# ...

# %%
with pd.ExcelWriter("Mobile_phone_data_from_Flipkart.xlsx") as writer:
    df.to_excel(writer, sheet_name="iphone_data",index=False),
    df_mat.to_excel(writer, sheet_name="motorola_data",index=False),
    df_sumsung.to_excel(writer, sheet_name="samsung_data",index=False),
    df_vivo.to_excel(writer, sheet_name="Vivo_data",index=False),
    df_realme.to_excel(writer, sheet_name="realme_data",index=False),
    df_oppo.to_excel(writer, sheet_name="oppo_data",index=False),
    df_redmi.to_excel(writer, sheet_name="redmi_data",index=False),
    df_poco.to_excel(writer, sheet_name="poco_data",index=False),
    df_google.to_excel(writer, sheet_name="google_pixel_data",index=False),
    df_infinix.to_excel(writer, sheet_name="Infinix_data",index=False)
